# %% [markdown]
# #Data

# %%
names = open('names.txt', 'r').read().split('\n')
print(names[:5])
# Out:
# ['emma', 'olivia', 'ava', 'isabella', 'sophia']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import torch

# %%
chars = [chr(c) for c in range(ord('a'), ord('z') + 1)]
chars.insert(0, ' ')
s2i = {s:i for i,s in enumerate(chars)}
i2s = {i:s for s,i in s2i.items()}

# %% [markdown]
# #Simple Bigram Model

# %%
bi_counter = {}
for name in names:
  s = ['<S>'] + list(name) + ['<E>']
  for i in range(len(s) - 1):
    c1 = s[i]
    c2 = s[i + 1]
    bi = (c1, c2)
    bi_counter[bi] = bi_counter.get(bi, 0) + 1

# %%
sorted_bigrams = list(reversed(sorted(bi_counter.items(), key = lambda t: t[1])))

# %%
print(sorted_bigrams)
# Out:
# [(('n', '<E>'), 6763), (('a', '<E>'), 6640), (('a', 'n'), 5438), (('<S>', 'a'), 4410), (('e', '<E>'), 3983), (('a', 'r'), 3264), (('e', 'l'), 3248), (('r', 'i'), 3033), (('n', 'a'), 2977), (('<S>', 'k'), 2963), (('l', 'e'), 2921), (('e', 'n'), 2675), (('l', 'a'), 2623), (('m', 'a'), 2590), (('<S>', 'm'), 2538), (('a', 'l'), 2528), (('i', '<E>'), 2489), (('l', 'i'), 2480), (('i', 'a'), 2445), (('<S>', 'j'), 2422), (('o', 'n'), 2411), (('h', '<E>'), 2409), (('r', 'a'), 2356), (('a', 'h'), 2332), (('h', 'a'), 2244), (('y', 'a'), 2143), (('i', 'n'), 2126), (('<S>', 's'), 2055), (('a', 'y'), 2050), (('y', '<E>'), 2007), (('e', 'r'), 1958), (('n', 'n'), 1906), (('y', 'n'), 1826), (('k', 'a'), 1731), (('n', 'i'), 1725), (('r', 'e'), 1697), (('<S>', 'd'), 1690), (('i', 'e'), 1653), (('a', 'i'), 1650), (('<S>', 'r'), 1639), (('a', 'm'), 1634), (('l', 'y'), 1588), (('<S>', 'l'), 1572), (('<S>', 'c'), 1542), (('<S>', 'e'), 1531), (('j', 'a'), 1473), (('r', '<E>'), 1377), (('n', 'e'), 1359), (('i', 'l'), 1345), (('l', 'l'), 1345), (('i', 's'), 1316), (('l', '<E>'), 1314), (('<S>', 't'), 1308), (('<S>', 'b'), 1306), (('d', 'a'), 1303), (('s', 'h'), 1285), (('d', 'e'), 1283), (('e', 'e'), 1271), (('m', 'i'), 1256), (('s', 'a'), 1201), (('s', '<E>'), 1169), (('<S>', 'n'), 1146), (('a', 's'), 1118), (('y', 'l'), 1104), (('e', 'y'), 1070), (('o', 'r'), 1059), (('a', 'd'), 1042), (('t', 'a'), 1027), (('<S>', 'z'), 929), (('v', 'i'), 911), (('k', 'e'), 895), (('s', 'e'), 884), (('<S>', 'h'), 874), (('r', 'o'), 869), (('e', 's'), 861), (('z', 'a'), 860), (('o', '<E>'), 855), (('i', 'r'), 849), (('b', 'r'), 842), (('a', 'v'), 834), (('e', 'i'), 818), (('m', 'e'), 818), (('c', 'a'), 815), (('i', 'y'), 779), (('r', 'y'), 773), (('e', 'm'), 769), (('s', 't'), 765), (('h', 'i'), 729), (('t', 'e'), 716), (('n', 'd'), 704), (('a', 'e'), 692), (('l', 'o'), 692), (('a', 't'), 687), (('s', 'i'), 684), (('e', 'a'), 679), (('h', 'e'), 674), (('d', 'i'), 674), (('<S>', 'g'), 669), (('t', 'o'), 667), (('c', 'h'), 664), (('b', 'e'), 655), (('t', 'h'), 647), (('v', 'a'), 642), (('o', 'l'), 619), (('<S>', 'i'), 591), (('i', 'o'), 588), (('e', 't'), 580), (('a', 'k'), 568), (('v', 'e'), 568), (('a', 'a'), 556), (('c', 'e'), 551), (('i', 't'), 541), (('a', 'b'), 541), (('<S>', 'y'), 535), (('t', 'i'), 532), (('s', 'o'), 531), (('d', '<E>'), 516), (('m', '<E>'), 516), (('<S>', 'p'), 515), (('k', 'i'), 509), (('i', 'c'), 509), (('o', 's'), 504), (('n', 'o'), 496), (('t', '<E>'), 483), (('j', 'o'), 479), (('u', 's'), 474), (('a', 'c'), 470), (('n', 'y'), 465), (('e', 'v'), 463), (('s', 's'), 461), (('m', 'o'), 452), (('i', 'k'), 445), (('n', 't'), 443), (('j', 'e'), 440), (('i', 'd'), 440), (('a', 'z'), 435), (('i', 'g'), 428), (('i', 'm'), 427), (('r', 'r'), 425), (('d', 'r'), 424), (('<S>', 'f'), 417), (('u', 'r'), 414), (('r', 'l'), 413), (('y', 's'), 401), (('<S>', 'o'), 394), (('e', 'd'), 384), (('a', 'u'), 381), (('c', 'o'), 380), (('k', 'y'), 379), (('d', 'o'), 378), (('<S>', 'v'), 376), (('t', 't'), 374), (('z', 'e'), 373), (('z', 'i'), 364), (('k', '<E>'), 363), (('g', 'h'), 360), (('t', 'r'), 352), (('k', 'o'), 344), (('t', 'y'), 341), (('g', 'e'), 334), (('g', 'a'), 330), (('l', 'u'), 324), (('b', 'a'), 321), (('d', 'y'), 317), (('c', 'k'), 316), (('k', 'h'), 307), (('<S>', 'w'), 307), (('y', 'e'), 301), (('u', 'l'), 301), (('y', 'r'), 291), (('h', 'o'), 287), (('m', 'y'), 287), (('w', 'a'), 280), (('s', 'l'), 279), (('n', 's'), 278), (('i', 'z'), 277), (('o', 'u'), 275), (('u', 'n'), 275), (('n', 'g'), 273), (('y', 'd'), 272), (('y', 'o'), 271), (('c', 'i'), 271), (('e', 'o'), 269), (('i', 'v'), 269), (('o', 'm'), 261), (('r', 'u'), 252), (('f', 'a'), 242), (('b', 'i'), 217), (('s', 'y'), 215), (('h', 'y'), 213), (('n', 'c'), 213), (('p', 'a'), 209), (('r', 't'), 208), (('q', 'u'), 206), (('h', 'r'), 204), (('p', 'h'), 204), (('j', 'u'), 202), (('g', 'r'), 201), (('p', 'e'), 197), (('n', 'l'), 195), (('y', 'i'), 192), (('r', 's'), 190), (('o', 'd'), 190),  ...

# %%
N = torch.zeros((27, 27), dtype=torch.int32)
for name in names:
  s = [' '] + list(name) + [' ']
  for i in range(len(s) - 1):
    index1 = s2i[s[i]]
    index2 = s2i[s[i + 1]]
    N[index1, index2] += 1

# %%
plt.figure(figsize=(16,16))
plt.imshow(N, cmap='Blues')
for i in range(27):
    for j in range(27):
        chstr = i2s[i] + i2s[j]
        plt.text(j, i, chstr, ha="center", va="bottom", color='gray')
        plt.text(j, i, N[i, j].item(), ha="center", va="top", color='gray')
plt.axis('off');

# %%
P = (N+1).float()
P /= P.sum(1, keepdim=True)

# %%
g = torch.Generator().manual_seed(2147483647)
i = 0

for k in range(20):
  new_name = ''

  while True:
    p = P[i]
    i = torch.multinomial(p, num_samples=1, replacement=True, generator=g).item()

    new_name += i2s[i]

    if i == 0:
      new_name = new_name[:-1]
      print(new_name)
      break
# Out:
# mor
# axx
# minaymoryles
# kondlaisah
# anchshizarie
# odaren
# iaddash
# h
# jhinatien
# egushl
# h
# br
# a
# jayn
# ilemannariaenien
# be
# f
# akiinela
# trttanakeroruceyaaxatona
# lamoynayrkiedengin

# %% [markdown]
# ##Negative Log Likelyhood

# %%
nll = 0.0
n = 0
for name in names:
  s = [' '] + list(name) + [' ']
  for i in range(len(s) - 1):
    index1 = s2i[s[i]]
    index2 = s2i[s[i + 1]]
    nll -= torch.log(P[index1, index2])
    n += 1
print(f'{nll=}')
print(f'{nll/n}')
# Out:
# nll=tensor(559951.5625)
# 2.4543561935424805

# %% [markdown]
# #Neural Network Bigram Model

# %%
xs, ys = [], []
for name in names:
  s = [' '] + list(name) + [' ']
  for i in range(len(s) - 1):
    index1 = s2i[s[i]]
    index2 = s2i[s[i + 1]]
    xs.append(index1)
    ys.append(index2)

xs = torch.tensor(xs)
ys = torch.tensor(ys)

# %%
import torch.nn.functional as F
x_enc = F.one_hot(xs, num_classes=27).float()

# %%
g = torch.Generator().manual_seed(2147483647)
W = torch.randn((27, 27), generator=g, requires_grad=True)
x_enc @ W
# Out:
# tensor([[ 1.9217, -0.1818,  1.5220,  0.5464,  0.4086, -1.9692, -0.8918,  0.3296,
#          -0.2513,  0.5503, -0.7517, -0.0066, -0.6311,  1.3431,  0.0380, -0.7165,
#           1.7206, -0.5215, -0.2325,  1.0774, -0.7602,  0.0090, -0.7922,  1.2307,
#          -0.5276, -1.3207, -0.7065]], grad_fn=<MmBackward0>)

# %%
# gradient descent
for k in range(300):
  # forward pass
  x_enc = F.one_hot(xs, num_classes=27).float()
  logits = x_enc @ W
  counts = logits.exp()
  probs = counts / counts.sum(1, keepdim=True)
  loss = -probs[torch.arange(len(probs)), ys].log().mean() + 0.001 * (W**2).mean()
  print(loss.item())

  # backward pass
  W.grad = None
  loss.backward()

  # update
  W.data -= 50 * W.grad
# Out:
# 3.759920358657837
# 3.3718738555908203
# 3.154751777648926
# 3.021059989929199
# 2.9283947944641113
# 2.861093044281006
# 2.8104305267333984
# 2.7708170413970947
# 2.738802671432495
# 2.712242603302002
# 2.6897668838500977
# 2.67047119140625
# 2.653733253479004
# 2.639101505279541
# 2.6262333393096924
# 2.6148574352264404
# 2.6047515869140625
# 2.595731019973755
# 2.587642192840576
# 2.580354690551758
# 2.5737600326538086
# 2.5677669048309326
# 2.562297821044922
# 2.5572876930236816
# 2.5526814460754395
# 2.548431873321533
# 2.544499158859253
# 2.5408501625061035
# 2.5374553203582764
# 2.534290313720703
# 2.5313332080841064
# 2.5285658836364746
# 2.5259716510772705
# 2.523536205291748
# 2.465477705001831
# 2.465424060821533
# 2.465371608734131
# 2.465319871902466
# 2.465268135070801
# 2.465217113494873
# 2.4651668071746826
# 2.4651176929473877
# 2.4650685787200928
# 2.465020179748535
# 2.464972496032715
# 2.4649248123168945
# 2.4648783206939697
# 2.4648325443267822
# 2.4647865295410156
# 2.4647414684295654
# 2.4646968841552734
# 2.4646527767181396
# 2.464609146118164
# 2.4645659923553467
# 2.4645235538482666
# 2.4644813537597656
# 2.464439868927002
# 2.4643986225128174
# 2.464357614517212
# 2.4643173217773438
# 2.464277505874634
# 2.464237928390503
# 2.4641990661621094
# 2.464160442352295
# 2.4641220569610596
# 2.4640843868255615
# 2.4640467166900635
# 2.464010000228882
# 2.463973045349121
# 2.4639370441436768
# 2.4639008045196533
# 2.4638655185699463
# 2.4638304710388184
# 2.4637954235076904
# 2.4637610912323
# 2.4637269973754883
# 2.463693141937256
# 2.4636600017547607
# 2.4636266231536865
# 2.4635937213897705
# 2.463561534881592
# 2.463529109954834
# 2.4634974002838135
# 2.463465929031372
# 2.4634346961975098
# 2.4634037017822266
# 2.4633731842041016
# 2.4633429050445557
# 2.463312864303589
# 2.463283061981201
# 2.4632534980773926
# 2.463224172592163
# 2.463195562362671
# 2.4631664752960205
# 2.4631381034851074
# 2.4631104469299316
# 2.4630823135375977
# 2.463054656982422
# 2.463027238845825
# 2.4630000591278076
# 2.462973117828369
# 2.462946891784668
# 2.4629201889038086
# 2.4628942012786865
# 2.4628682136535645
# 2.4628424644470215
# 2.4628169536590576
# 2.462791681289673
# 2.462766647338867
# 2.4627416133880615
# 2.462717056274414
# 2.4626927375793457
# 2.4626684188842773
# 2.462644577026367
# 2.462620735168457
# 2.462597131729126
# 2.462574005126953
# 2.462550401687622
# 2.4625275135040283
# 2.4625048637390137
# 2.46248197555542
# 2.4624600410461426
# 2.462437391281128
# 2.4624152183532715
# 2.4623935222625732
# 2.462371826171875
# 2.462350368499756
# 2.4623289108276367
# 2.462307929992676
# 2.4622867107391357
# 2.462265968322754
# 2.462245225906372
# 2.4622247219085693
# 2.462204694747925
# 2.462184429168701
# 2.4621644020080566
# 2.4621448516845703
# 2.462124824523926
# 2.4621050357818604
# 2.462085723876953
# 2.462066173553467
# 2.462047576904297
# 2.4620285034179688
# 2.4620094299316406
# 2.4619908332824707
# 2.46197247505188
# 2.461954355239868
# 2.4619359970092773
# 2.4619178771972656
# 2.461899757385254
# 2.4618818759918213

# %%
g = torch.Generator().manual_seed(2147483647)
i = 0

for k in range(20):
  new_name = ''

  while True:
    x_enc = F.one_hot(torch.tensor([i]), num_classes=27).float()
    logits = x_enc @ W
    counts = logits.exp()
    p = counts / counts.sum(1, keepdim=True)

    i = torch.multinomial(p, num_samples=1, replacement=True, generator=g).item()

    new_name += i2s[i]

    if i == 0:
      new_name = new_name[:-1]
      print(new_name)
      break
# Out:
# mor
# axx
# minaymoryles
# kondlaisah
# anchshizarie
# odaren
# iaddash
# h
# jionatien
# egushk
# ga
# t
# a
# jayn
# ilemannariaenien
# be
# f
# akiinela
# trttanakeroruceyaaxatona
# lamoynayrkhadengin
